# %%
print("test2")
# Out:
# test2

# %%
import matplotlib.pyplot as plt
import numpy as np

# Erzeugen von Daten für den Plot
x = np.linspace(0, 2*np.pi, 100)  # Erzeugt 100 Punkte von 0 bis 2*pi
y = np.sin(x)  # Berechnet den Sinus für jeden Punkt

# Erstellen des Plots
plt.plot(x, y, label='Sinusfunktion')  # Linienplot der Sinusfunktion

# Hinzufügen von Beschriftungen und einem Titel
plt.xlabel('X-Achse')
plt.ylabel('Y-Achse')
plt.title('Sinusfunktion')

# Hinzufügen einer Legende
plt.legend()

# Anzeigen des Plots
plt.show()
